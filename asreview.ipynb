# %%
import pandas as pd

df = pd.read_csv("WOS.csv")

# %%
df.head(5)
# Out:
#    ID Publication Type                                      Article Title  \
# 0   1                C  Enhancing Visual Information Extraction with L...
# 1   2                C  FetalExtract-LLM: Structured Information Extra...
# 2   3                J  Leveraging Generative AI and Large Language Mo...
# 3   4                J  Use of Machine Learning and Large Language Mod...
# 4   5                J  THE INTEGRATION OF GENERATIVE ARTIFICIAL INTEL...
#
#                                         Source Title  \
# 0  PATTERN RECOGNITION AND COMPUTER VISION, PRCV ...
# 1  PERINATAL, PRETERM AND PAEDIATRIC IMAGE ANALYS...
# 2             KOREAN JOURNAL OF CHEMICAL ENGINEERING
# 3  ANNUAL REVIEW OF CHEMICAL AND BIOMOLECULAR ENG...
# 4                                      PRISMA SOCIAL
#
#                                     Conference Title  \
# 0  7th Chinese Conference on Pattern Recognition ...
# 1  10th International Workshop on Perinatal Prete...
# ...

# %%
# Keep only required columns
df = df.rename(columns={
    "Article Title": "title",
    "Abstract": "abstract"
})

df = df[["title", "abstract"]]

df.to_csv("papers_asreview.csv", index=False)

# %%
df.head()
# Out:
#                                                title  \
# 0  Enhancing Visual Information Extraction with L...
# 1  FetalExtract-LLM: Structured Information Extra...
# 2  Leveraging Generative AI and Large Language Mo...
# 3  Use of Machine Learning and Large Language Mod...
# 4  THE INTEGRATION OF GENERATIVE ARTIFICIAL INTEL...
#
#                                             abstract
# 0  Recently, leveraging large language models (LL...
# 1  Magnetic resonance imaging (MRI) is essential ...
# 2  Process systems engineering (PSE) has long bee...
# 3  Rich information in the chemical literature pr...
# 4  The field of artificial intelligence (AI) has ...

# %%
from asreview.io import load_dataset

dataset = load_dataset("papers_asreview.csv")

project.add_dataset(dataset)
# Out:
# c:\Users\ikaqu\Desktop\PROJECT\automatic-SLR\.venv\Lib\site-packages\asreview\utils.py:21: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from asreview.io import load_dataset
#       2
#       3 dataset = load_dataset("papers_asreview.csv")
#       4
#
# ImportError: cannot import name 'load_dataset' from 'asreview.io' (c:\Users\ikaqu\Desktop\PROJECT\automatic-SLR\.venv\Lib\site-packages\asreview\io\__init__.py)
